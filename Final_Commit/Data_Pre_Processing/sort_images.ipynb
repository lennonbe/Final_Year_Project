# %%
import cv2, os, shutil
import numpy as np
from PIL import Image

# %%
# opening folders with data in them
flooding_true = "/content/drive/MyDrive/Third_Year_Project/Data/content/data/output/test/FloodingTrue"
flooding_false = "/content/drive/MyDrive/Third_Year_Project/Data/content/data/output/test/FloodingFalse"

# %%
sorted = []
used = []
filenames = []
for filename in os.listdir(flooding_true):

    temp = filename[0:4]
    if temp not in sorted:

        sorted.append(temp)
        filenames.append(filename)

sorted2 = []
used2 = []
filenames2 = []
for filename in os.listdir(flooding_false):

    temp = filename[0:4]
    if temp not in sorted2 and temp in sorted:

        sorted2.append(temp)
        filenames2.append(filename)

sorted = [i for i in sorted if i in sorted2]
#filenames = [i for i in filenames if i in filenames2]

# %%
used = []
final_filenames = []
for filename in filenames:

    temp_head = filename[0:4]
    temp_tail = filename[18:]

    for filename2 in filenames2:

        temp_head2 = filename2[0:4]
        temp_tail2 = filename2[19:]

        if temp_head == temp_head2 and temp_head not in used and temp_head2 not in used and filename:
            used.append(temp_head)
            final_filenames.append(filename)

# %%
#print(sorted)
#print(sorted2)
sorted.sort()
sorted2.sort()
print(sorted)
print(sorted2)
print('-------------------------------------------------------')
final_filenames.sort()
filenames2.sort()
print(final_filenames)
print(filenames2)
print('-------------------------------------------------------')
# Out:
# ['0144', '0146', '0149', '0154', '0176', '0186', '0187', '0193', '0205', '0208', '0216', '0218', '0223', '0225', '0227', '0229', '0230', '0231', '0232', '0235', '0236', '0238', '0240', '0241', '0243', '0245', '0248', '0249', '0253', '0254', '0255', '0256', '0257', '0258', '0259', '0260', '0261', '0262', '0263', '0266', '0267', '0271', '0272', '0273', '0274', '0276', '0277', '0278', '0279', '0280', '0282', '0285', '0286', '0287', '0288', '0318', '0321', '0323']
# ['0144', '0146', '0149', '0154', '0176', '0186', '0187', '0193', '0205', '0208', '0216', '0218', '0223', '0225', '0227', '0229', '0230', '0231', '0232', '0235', '0236', '0238', '0240', '0241', '0243', '0245', '0248', '0249', '0253', '0254', '0255', '0256', '0257', '0258', '0259', '0260', '0261', '0262', '0263', '0266', '0267', '0271', '0272', '0273', '0274', '0276', '0277', '0278', '0279', '0280', '0282', '0285', '0286', '0287', '0288', '0318', '0321', '0323']
# -------------------------------------------------------
# ['0144_FloodingTrue_9.png', '0146_FloodingTrue_8.png', '0149_FloodingTrue_9.png', '0154_FloodingTrue_9.png', '0176_FloodingTrue_5.png', '0186_FloodingTrue_10.png', '0187_FloodingTrue_5.png', '0193_FloodingTrue_6.png', '0205_FloodingTrue_6.png', '0208_FloodingTrue_10.png', '0216_FloodingTrue_6.png', '0218_FloodingTrue_8.png', '0223_FloodingTrue_11.png', '0225_FloodingTrue_16.png', '0227_FloodingTrue_13.png', '0229_FloodingTrue_17.png', '0230_FloodingTrue_15.png', '0231_FloodingTrue_11.png', '0232_FloodingTrue_12.png', '0235_FloodingTrue_12.png', '0236_FloodingTrue_16.png', '0238_FloodingTrue_17.png', '0240_FloodingTrue_16.png', '0241_FloodingTrue_14.png', '0243_FloodingTrue_14.png', '0245_FloodingTrue_14.png', '0248_FloodingTrue_9.png', '0249_FloodingTrue_14.png', '0253_FloodingTrue_21.png', '0254_FloodingTrue_24.png', '0255_FloodingTrue_23.png', '0256_FloodingTrue_16.png', '0257_FloodingTrue_16.png', '0258_FloodingTrue_23.png', '0259_FloodingTrue_22.png', '0260_FloodingTrue_21.png', '0261_FloodingTrue_22.png', '0262_FloodingTrue_15.png', '0263_FloodingTrue_23.png', '0266_FloodingTrue_19.png', '0267_FloodingTrue_23.png', '0271_FloodingTrue_21.png', '0272_FloodingTrue_18.png', '0273_FloodingTrue_23.png', '0274_FloodingTrue_21.png', '0276_FloodingTrue_24.png', '0277_FloodingTrue_23.png', '0278_FloodingTrue_18.png', '0279_FloodingTrue_17.png', '0280_FloodingTrue_19.png', '0282_FloodingTrue_16.png', '0285_FloodingTrue_14.png', '0286_FloodingTrue_15.png', '0287_FloodingTrue_24.png', '0288_FloodingTrue_22.png', '0318_FloodingTrue_2.png', '0321_FloodingTrue_4.png', '0323_FloodingTrue_3.png']
# ['0144_FloodingFalse_2.png', '0146_FloodingFalse_2.png', '0149_FloodingFalse_4.png', '0154_FloodingFalse_4.png', '0176_FloodingFalse_2.png', '0186_FloodingFalse_3.png', '0187_FloodingFalse_1.png', '0193_FloodingFalse_2.png', '0205_FloodingFalse_3.png', '0208_FloodingFalse_1.png', '0216_FloodingFalse_3.png', '0218_FloodingFalse_2.png', '0223_FloodingFalse_5.png', '0225_FloodingFalse_6.png', '0227_FloodingFalse_3.png', '0229_FloodingFalse_2.png', '0230_FloodingFalse_2.png', '0231_FloodingFalse_8.png', '0232_FloodingFalse_1.png', '0235_FloodingFalse_1.png', '0236_FloodingFalse_5.png', '0238_FloodingFalse_6.png', '0240_FloodingFalse_4.png', '0241_FloodingFalse_3.png', '0243_FloodingFalse_5.png', '0245_FloodingFalse_5.png', '0248_FloodingFalse_7.png', '0249_FloodingFalse_2.png', '0253_FloodingFalse_3.png', '0254_FloodingFalse_1.png', '0255_FloodingFalse_5.png', '0256_FloodingFalse_13.png', '0257_FloodingFalse_12.png', '0258_FloodingFalse_3.png', '0259_FloodingFalse_9.png', '0260_FloodingFalse_8.png', '0261_FloodingFalse_9.png', '0262_FloodingFalse_2.png', '0263_FloodingFalse_8.png', '0266_FloodingFalse_13.png', '0267_FloodingFalse_6.png', '0271_FloodingFalse_8.png', '0272_FloodingFalse_9.png', '0273_FloodingFalse_3.png', '0274_FloodingFalse_9.png', '0276_FloodingFalse_5.png', '0277_FloodingFalse_1.png', '0278_FloodingFalse_3.png', '0279_FloodingFalse_8.png', '0280_FloodingFalse_10.png', '0282_FloodingFalse_3.png', '0285_FloodingFalse_5.png', '0286_FloodingFalse_9.png', '0287_FloodingFalse_4.png', '0288_FloodingFalse_9.png', '0318_FloodingFalse_1.png', '0321_FloodingFalse_1.png', '0323_FloodingFalse_1.png']
# -------------------------------------------------------

# %%
for i in range(len(final_filenames)):
    shutil.copy(flooding_true + '/' + final_filenames[i],'/content/drive/MyDrive/Third_Year_Project/Data/content/Flooding_True/' + str(i) + '.png')

for i in range(len(filenames2)):

    shutil.copy(flooding_true + '/' + final_filenames[i],'/content/drive/MyDrive/Third_Year_Project/Data/content/Flooding_False/' + str(i) + '.png')
